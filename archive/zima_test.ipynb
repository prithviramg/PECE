# %%
from kiteconnect import KiteTicker

# %%
token = "Z6y8mRAmd80eBlKInWT4sFy1G7ilS2NwNT8YO/6VK23Q0WrnPsIeT3r/7YaRLq/uEDZiyTMc5sI5O7WK614iy0xSN4fSmuQ8lYz+lMFtJJfPsrhdPPOadA=="
kite = kite_trade.KiteApp(token)
kws = kite.kws()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 token = "Z6y8mRAmd80eBlKInWT4sFy1G7ilS2NwNT8YO/6VK23Q0WrnPsIeT3r/7YaRLq/uEDZiyTMc5sI5O7WK614iy0xSN4fSmuQ8lYz+lMFtJJfPsrhdPPOadA=="
# ----> 2 kite = kite_trade.KiteApp(token)
#       3 kws = kite.kws()
#
# NameError: name 'kite_trade' is not defined

# %%
print(kite.margins())
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File c:\Users\uie54988\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...
